# %% [markdown]
# # Libaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.preprocessing import KBinsDiscretizer
from sklearn.impute import SimpleImputer

from scipy.stats import ks_2samp
from varclushi import VarClusHi
from sklearn.feature_selection import VarianceThreshold

from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns',500)

# %% [markdown]
# # Functions

# %%
# Requencies
def freq(df, var):
    if type(var) != list:
        var = [var]
    
    for v in var:
        aux = df[v].value_counts().to_frame().rename(columns={v:'FA'})
        aux['FR'] = aux['FA'] / aux['FA'].sum()
        aux[['FAA','FRA']] = aux.apply( np.cumsum )
        print(f"Frequencies table for variable {v} \n")    
        print(aux,"\n")

# %%
#Normalize
def normalize(df, v, umbral):
    #
    aux = df[v].value_counts(True).to_frame()
    aux[f'n_{v}'] = np.where( aux[v] < umbral , 'SMALL_CATEGORIES', aux.index   )
    moda = aux.head(1)[f'n_{v}'].values[0]
    if aux.loc[aux[f'n_{v}'] == 'SMALL_CATEGORIES'][v].sum() < umbral: 
        aux[f'n_{v}'].replace({'SMALL_CATEGORIES':moda},inplace=True)

    aux.drop(v,axis=1, inplace=True)
    aux.reset_index(inplace=True)

    return df.merge(aux, left_on=[v], right_on='index',how='inner').drop('index',axis=1)

# %%
#Discretizing
def discretizar(df,v,k):
    
    kb = KBinsDiscretizer( n_bins= k , encode='ordinal', strategy='kmeans')
    kb.fit( df[[v]] )
    df[f'd_{v}_{k}']  = pd.cut( df[v], bins=kb.bin_edges_[0] , include_lowest=True  ).astype(str)
    
    return df

# %%
def calculo_iv(df, v, tgt , um):
    aux = df.pivot_table( index = v , 
                          columns = tgt , 
                          values = um , 
                         aggfunc = 'count', 
                         fill_value = 0 )
    
    aux[list(range(2))] = aux/aux.apply(np.sum)
    aux['w'] = np.log( aux[0] / aux[1] )
    aux['iv'] = ( aux[0] - aux[1] ) * aux['w']
    
    return v, aux['iv'].sum()

# %%
def codificacion_woe(df,v,tgt,um):
    
    aux = df.pivot_table(index=v,
                         columns=tgt,
                         values=um,
                         aggfunc='count',
                         fill_value=0)
    
    aux[list(range(2))] = aux/aux.apply(np.sum)
    
    aux['w'] = np.log(aux[0]/aux[1])
    
    aux.drop(range(2),axis=1,inplace=True)
    
    aux = aux.to_dict()['w']
    
    return v,aux

# %% [markdown]
# # Data Reading

# %%
df = pd.read_csv("../Datasets/Examen/diabetes_examen/diabetes.csv")

# %%
df.head()
# Out:
#    id  encounter_id  patient_nbr             race  gender      age weight  \
# 0   1       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1   2        149190     55629189        Caucasian  Female  [10-20)      ?
# 2   3         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3   4        500364     82442376        Caucasian    Male  [30-40)      ?
# 4   5         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital payer_code         medical_specialty  num_lab_procedures  \
# 0                 1          ?  Pediatrics-Endocrinology                  41
# 1                 3          ?                         ?                  59
# 2                 2          ?                         ?                  11
# 3                 2          ?                         ?                  44
# 4                 1          ?                         ?                  51
#
#    num_procedures  num_medications  number_outpatient  number_emergency  \
# 0               0                1                  0                 0
# 1               0               18                  0                 0
# 2               5               13                  2                 0
# 3               1               16                  0                 0
# 4               0                8                  0                 0
#
#    number_inpatient  diag_1  diag_2 diag_3  number_diagnoses max_glu_serum  \
# 0                 0  250.83       ?      ?                 1          None
# 1                 0     276  250.01    255                 9          None
# 2                 1     648     250    V27                 6          None
# 3                 0       8  250.43    403                 7          None
# 4                 0     197     157    250                 5          None
#
#   A1Cresult metformin repaglinide nateglinide chlorpropamide glimepiride  \
# 0      None        No          No          No             No          No
# 1      None        No          No          No             No          No
# 2      None        No          No          No             No          No
# 3      None        No          No          No             No          No
# 4      None        No          No          No             No          No
#
#   acetohexamide glipizide glyburide tolbutamide pioglitazone rosiglitazone  \
# 0            No        No        No          No           No            No
# 1            No        No        No          No           No            No
# 2            No    Steady        No          No           No            No
# 3            No        No        No          No           No            No
# 4            No    Steady        No          No           No            No
#
#   acarbose miglitol troglitazone tolazamide examide citoglipton insulin  \
# 0       No       No           No         No      No          No      No
# 1       No       No           No         No      No          No      Up
# 2       No       No           No         No      No          No      No
# 3       No       No           No         No      No          No      Up
# 4       No       No           No         No      No          No  Steady
#
#   glyburide.metformin glipizide.metformin glimepiride.pioglitazone  \
# 0                  No                  No                       No
# 1                  No                  No                       No
# 2                  No                  No                       No
# 3                  No                  No                       No
# 4                  No                  No                       No
#
#   metformin.rosiglitazone metformin.pioglitazone change diabetesMed readmitted
# 0                      No                     No     No          No         NO
# 1                      No                     No     Ch         Yes        >30
# 2                      No                     No     No         Yes         NO
# 3                      No                     No     Ch         Yes         NO
# 4                      No                     No     Ch         Yes         NO

# %% [markdown]
# # Cleaning / pre-treatment

# %%
df.shape, len(df.id.unique())
# Out:
# ((101766, 51), 101766)

# %%
#We can drop the id column as it is the same as the index
#We can also drop "encounter_id" as it is the id at the hospital and not the id of the customer
df.id
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 101761    101762
# 101762    101763
# 101763    101764
# 101764    101765
# 101765    101766
# Name: id, Length: 101766, dtype: int64

# %%
#We're not using Patient Number as um as it can affect our analysis in the predictive power
#Instead, we're using each admission to the hospital as um (encounter_id)
df.drop(columns=["id", "patient_nbr"], inplace=True)
#df.rename(columns={"patient_nbr": "patientID"}, inplace=True)
df.columns = [c.replace('.','_') for c in df.columns.tolist()]

# %%
#We replace the ? value for nan
df = df.replace("?", np.nan)

# %%
df.head()
# Out:
#    encounter_id             race  gender      age weight  admission_type_id  \
# 0       2278392        Caucasian  Female   [0-10)    NaN                  6
# 1        149190        Caucasian  Female  [10-20)    NaN                  1
# 2         64410  AfricanAmerican  Female  [20-30)    NaN                  1
# 3        500364        Caucasian    Male  [30-40)    NaN                  1
# 4         16680        Caucasian    Male  [40-50)    NaN                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                        25                    1                 1        NaN
# 1                         1                    7                 3        NaN
# 2                         1                    7                 2        NaN
# 3                         1                    7                 2        NaN
# 4                         1                    7                 1        NaN
#
#           medical_specialty  num_lab_procedures  num_procedures  \
# 0  Pediatrics-Endocrinology                  41               0
# 1                       NaN                  59               0
# 2                       NaN                  11               5
# 3                       NaN                  44               1
# 4                       NaN                  51               0
#
#    num_medications  number_outpatient  number_emergency  number_inpatient  \
# 0                1                  0                 0                 0
# 1               18                  0                 0                 0
# 2               13                  2                 0                 1
# 3               16                  0                 0                 0
# 4                8                  0                 0                 0
#
#    diag_1  diag_2 diag_3  number_diagnoses max_glu_serum A1Cresult metformin  \
# 0  250.83     NaN    NaN                 1          None      None        No
# 1     276  250.01    255                 9          None      None        No
# 2     648     250    V27                 6          None      None        No
# 3       8  250.43    403                 7          None      None        No
# 4     197     157    250                 5          None      None        No
#
#   repaglinide nateglinide chlorpropamide glimepiride acetohexamide glipizide  \
# 0          No          No             No          No            No        No
# 1          No          No             No          No            No        No
# 2          No          No             No          No            No    Steady
# 3          No          No             No          No            No        No
# 4          No          No             No          No            No    Steady
#
#   glyburide tolbutamide pioglitazone rosiglitazone acarbose miglitol  \
# 0        No          No           No            No       No       No
# 1        No          No           No            No       No       No
# 2        No          No           No            No       No       No
# 3        No          No           No            No       No       No
# 4        No          No           No            No       No       No
#
#   troglitazone tolazamide examide citoglipton insulin glyburide_metformin  \
# 0           No         No      No          No      No                  No
# 1           No         No      No          No      Up                  No
# 2           No         No      No          No      No                  No
# 3           No         No      No          No      Up                  No
# 4           No         No      No          No  Steady                  No
#
#   glipizide_metformin glimepiride_pioglitazone metformin_rosiglitazone  \
# 0                  No                       No                      No
# 1                  No                       No                      No
# 2                  No                       No                      No
# 3                  No                       No                      No
# 4                  No                       No                      No
#
#   metformin_pioglitazone change diabetesMed readmitted
# 0                     No     No          No         NO
# 1                     No     Ch         Yes        >30
# 2                     No     No         Yes         NO
# 3                     No     Ch         Yes         NO
# 4                     No     Ch         Yes         NO

# %%
um = ["encounter_id"]
tgt = ["diabetesMed"]
vard = ["race", "gender", "age", "weight", "payer_code", "medical_specialty", "max_glu_serum", "A1Cresult", "metformin", "repaglinide",
        "nateglinide", "chlorpropamide", "glimepiride", "acetohexamide", "glipizide", "glyburide", "tolbutamide", "pioglitazone", "rosiglitazone",
        "acarbose", "miglitol", "troglitazone", "tolazamide", "examide", "citoglipton", "insulin", "glyburide_metformin", "glipizide_metformin",
        "glimepiride_pioglitazone", "metformin_rosiglitazone", "metformin_pioglitazone", "change", "readmitted"]
varc = [c for c in df.columns.tolist() if c not in vard]
varc = [c for c in varc if c not in um]
varc = [c for c in varc if c not in tgt]

# %%
df[varc].dtypes
# Out:
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# dtype: object

# %%
df[vard].dtypes
# Out:
# race                        object
# gender                      object
# age                         object
# weight                      object
# payer_code                  object
# medical_specialty           object
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# examide                     object
# citoglipton                 object
# insulin                     object
# glyburide_metformin         object
# glipizide_metformin         object
# glimepiride_pioglitazone    object
# metformin_rosiglitazone     object
# metformin_pioglitazone      object
# change                      object
# readmitted                  object
# dtype: object

# %%
#We need to change the type for diag_x columns but some values start with V or E
temp = ["diag_1", "diag_2", "diag_3"]
for col in temp:
    df[col] = df[col].apply(lambda x : x[1:] if str(x).startswith(("V","E")) else x)

df = df.astype({'diag_1':'float','diag_2':'float','diag_3':'float'})

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## Discrete Variables

# %% [markdown]
# ### Replacing NaN for "SIN CATEGORIA"

# %%
df.shape
# Out:
# (101766, 49)

# %%
for v in vard:
    df[v] = df[v].fillna("SIN CATEGORIA")

# %% [markdown]
# ### Frequencies

# %%
for v in vard:
    freq(df,v)
# Out:
# Frequencies table for variable race
#
#                     FA        FR     FAA       FRA
# Caucasian        76099  0.747784   76099  0.747784
# AfricanAmerican  19210  0.188766   95309  0.936551
# SIN CATEGORIA     2273  0.022336   97582  0.958886
# Hispanic          2037  0.020017   99619  0.978903
# Other             1506  0.014799  101125  0.993701
# Asian              641  0.006299  101766  1.000000
#
# Frequencies table for variable gender
#
#                     FA        FR     FAA       FRA
# Female           54708  0.537586   54708  0.537586
# Male             47055  0.462384  101763  0.999971
# Unknown/Invalid      3  0.000029  101766  1.000000
#
# Frequencies table for variable age
#
#              FA        FR     FAA       FRA
# [70-80)   26068  0.256156   26068  0.256156
# [60-70)   22483  0.220928   48551  0.477085
# [50-60)   17256  0.169565   65807  0.646650
# [80-90)   17197  0.168986   83004  0.815636
# [40-50)    9685  0.095169   92689  0.910805
# [30-40)    3775  0.037095   96464  0.947900
# [90-100)   2793  0.027445   99257  0.975345
# [20-30)    1657  0.016282  100914  0.991628
# [10-20)     691  0.006790  101605  0.998418
# [0-10)      161  0.001582  101766  1.000000
#
# Frequencies table for variable weight
#
#                   FA        FR     FAA       FRA
# SIN CATEGORIA  98569  0.968585   98569  0.968585
# [75-100)        1336  0.013128   99905  0.981713
# [50-75)          897  0.008814  100802  0.990527
# [100-125)        625  0.006142  101427  0.996669
# [125-150)        145  0.001425  101572  0.998094
# [25-50)           97  0.000953  101669  0.999047
# [0-25)            48  0.000472  101717  0.999519
# [150-175)         35  0.000344  101752  0.999862
# [175-200)         11  0.000108  101763  0.999971
# >200               3  0.000029  101766  1.000000
#
# Frequencies table for variable payer_code
#
#                   FA        FR     FAA       FRA
# SIN CATEGORIA  40256  0.395574   40256  0.395574
# MC             32439  0.318761   72695  0.714335
# HM              6274  0.061651   78969  0.775986
# SP              5007  0.049201   83976  0.825187
# BC              4655  0.045742   88631  0.870929
# MD              3532  0.034707   92163  0.905636
# CP              2533  0.024890   94696  0.930527
# UN              2448  0.024055   97144  0.954582
# CM              1937  0.019034   99081  0.973616
# OG              1033  0.010151  100114  0.983767
# PO               592  0.005817  100706  0.989584
# DM               549  0.005395  101255  0.994979
# CH               146  0.001435  101401  0.996413
# WC               135  0.001327  101536  0.997740
# OT                95  0.000934  101631  0.998673
# MP                79  0.000776  101710  0.999450
# SI                55  0.000540  101765  0.999990
# FR                 1  0.000010  101766  1.000000
#
# Frequencies table for variable medical_specialty
#
#                                   FA        FR     FAA       FRA
# SIN CATEGORIA                  49949  0.490822   49949  0.490822
# InternalMedicine               14635  0.143810   64584  0.634632
# Emergency/Trauma                7565  0.074337   72149  0.708970
# Family/GeneralPractice          7440  0.073109   79589  0.782078
# Cardiology                      5352  0.052591   84941  0.834670
# ...                              ...       ...     ...       ...
# SportsMedicine                     1  0.000010  101762  0.999961
# Speech                             1  0.000010  101763  0.999971
# Perinatology                       1  0.000010  101764  0.999980
# Neurophysiology                    1  0.000010  101765  0.999990
# Pediatrics-InfectiousDiseases      1  0.000010  101766  1.000000
#
# [73 rows x 4 columns]
#
# Frequencies table for variable max_glu_serum
#
#          FA        FR     FAA       FRA
# None  96420  0.947468   96420  0.947468
# Norm   2597  0.025519   99017  0.972987
# >200   1485  0.014592  100502  0.987579
# >300   1264  0.012421  101766  1.000000
#
# Frequencies table for variable A1Cresult
#
#          FA        FR     FAA       FRA
# None  84748  0.832773   84748  0.832773
# >8     8216  0.080734   92964  0.913507
# Norm   4990  0.049034   97954  0.962542
# >7     3812  0.037458  101766  1.000000
#
# Frequencies table for variable metformin
#
#            FA        FR     FAA       FRA
# No      81778  0.803589   81778  0.803589
# Steady  18346  0.180276  100124  0.983865
# Up       1067  0.010485  101191  0.994350
# Down      575  0.005650  101766  1.000000
#
# Frequencies table for variable repaglinide
#
#             FA        FR     FAA       FRA
# No      100227  0.984877  100227  0.984877
# Steady    1384  0.013600  101611  0.998477
# Up         110  0.001081  101721  0.999558
# Down        45  0.000442  101766  1.000000
#
# Frequencies table for variable nateglinide
#
#             FA        FR     FAA       FRA
# No      101063  0.993092  101063  0.993092
# Steady     668  0.006564  101731  0.999656
# Up          24  0.000236  101755  0.999892
# Down        11  0.000108  101766  1.000000
#
# Frequencies table for variable chlorpropamide
#
#             FA        FR     FAA       FRA
# No      101680  0.999155  101680  0.999155
# Steady      79  0.000776  101759  0.999931
# Up           6  0.000059  101765  0.999990
# Down         1  0.000010  101766  1.000000
#
# Frequencies table for variable glimepiride
#
#            FA        FR     FAA       FRA
# No      96575  0.948991   96575  0.948991
# Steady   4670  0.045890  101245  0.994880
# Up        327  0.003213  101572  0.998094
# Down      194  0.001906  101766  1.000000
#
# Frequencies table for variable acetohexamide
#
#             FA       FR     FAA      FRA
# No      101765  0.99999  101765  0.99999
# Steady       1  0.00001  101766  1.00000
#
# Frequencies table for variable glipizide
#
#            FA        FR     FAA       FRA
# No      89080  0.875341   89080  0.875341
# Steady  11356  0.111589  100436  0.986931
# Up        770  0.007566  101206  0.994497
# Down      560  0.005503  101766  1.000000
#
# Frequencies table for variable glyburide
#
#            FA        FR     FAA       FRA
# No      91116  0.895348   91116  0.895348
# Steady   9274  0.091131  100390  0.986479
# Up        812  0.007979  101202  0.994458
# Down      564  0.005542  101766  1.000000
#
# Frequencies table for variable tolbutamide
#
#             FA        FR     FAA       FRA
# No      101743  0.999774  101743  0.999774
# Steady      23  0.000226  101766  1.000000
#
# Frequencies table for variable pioglitazone
#
#            FA        FR     FAA       FRA
# No      94438  0.927992   94438  0.927992
# Steady   6976  0.068549  101414  0.996541
# Up        234  0.002299  101648  0.998840
# Down      118  0.001160  101766  1.000000
#
# Frequencies table for variable rosiglitazone
#
#            FA        FR     FAA       FRA
# No      95401  0.937455   95401  0.937455
# Steady   6100  0.059941  101501  0.997396
# Up        178  0.001749  101679  0.999145
# Down       87  0.000855  101766  1.000000
#
# Frequencies table for variable acarbose
#
#             FA        FR     FAA       FRA
# No      101458  0.996973  101458  0.996973
# Steady     295  0.002899  101753  0.999872
# Up          10  0.000098  101763  0.999971
# Down         3  0.000029  101766  1.000000
#
# Frequencies table for variable miglitol
#
#             FA        FR     FAA       FRA
# No      101728  0.999627  101728  0.999627
# Steady      31  0.000305  101759  0.999931
# Down         5  0.000049  101764  0.999980
# Up           2  0.000020  101766  1.000000
#
# Frequencies table for variable troglitazone
#
#             FA        FR     FAA       FRA
# No      101763  0.999971  101763  0.999971
# Steady       3  0.000029  101766  1.000000
#
# Frequencies table for variable tolazamide
#
#             FA        FR     FAA       FRA
# No      101727  0.999617  101727  0.999617
# Steady      38  0.000373  101765  0.999990
# Up           1  0.000010  101766  1.000000
#
# Frequencies table for variable examide
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable citoglipton
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable insulin
#
#            FA        FR     FAA       FRA
# No      47383  0.465607   47383  0.465607
# Steady  30849  0.303137   78232  0.768744
# Down    12218  0.120060   90450  0.888804
# Up      11316  0.111196  101766  1.000000
#
# Frequencies table for variable glyburide_metformin
#
#             FA        FR     FAA       FRA
# No      101060  0.993063  101060  0.993063
# Steady     692  0.006800  101752  0.999862
# Up           8  0.000079  101760  0.999941
# Down         6  0.000059  101766  1.000000
#
# Frequencies table for variable glipizide_metformin
#
#             FA        FR     FAA       FRA
# No      101753  0.999872  101753  0.999872
# Steady      13  0.000128  101766  1.000000
#
# Frequencies table for variable glimepiride_pioglitazone
#
#             FA       FR     FAA      FRA
# No      101765  0.99999  101765  0.99999
# Steady       1  0.00001  101766  1.00000
#
# Frequencies table for variable metformin_rosiglitazone
#
#             FA       FR     FAA      FRA
# No      101764  0.99998  101764  0.99998
# Steady       2  0.00002  101766  1.00000
#
# Frequencies table for variable metformin_pioglitazone
#
#             FA       FR     FAA      FRA
# No      101765  0.99999  101765  0.99999
# Steady       1  0.00001  101766  1.00000
#
# Frequencies table for variable change
#
#        FA        FR     FAA       FRA
# No  54755  0.538048   54755  0.538048
# Ch  47011  0.461952  101766  1.000000
#
# Frequencies table for variable readmitted
#
#         FA        FR     FAA       FRA
# NO   54864  0.539119   54864  0.539119
# >30  35545  0.349282   90409  0.888401
# <30  11357  0.111599  101766  1.000000

# %% [markdown]
# ### Normalizing

# %%
for v in vard:
    df = normalize(df,v,0.05)

# %%
df.head()
# Out:
#    encounter_id       race  gender      age         weight  admission_type_id  \
# 0       2278392  Caucasian  Female   [0-10)  SIN CATEGORIA                  6
# 1      53963346  Caucasian  Female   [0-10)  SIN CATEGORIA                  3
# 2      42008934  Caucasian    Male   [0-10)  SIN CATEGORIA                  1
# 3      68750328  Caucasian    Male   [0-10)  SIN CATEGORIA                  1
# 4      13138032  Caucasian  Female  [10-20)  SIN CATEGORIA                  2
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                        25                    1                 1
# 1                         1                    1                 2
# 2                         1                    7                 1
# 3                         1                    7                 1
# 4                         1                    1                 2
#
#       payer_code         medical_specialty  num_lab_procedures  \
# 0  SIN CATEGORIA  Pediatrics-Endocrinology                  41
# 1  SIN CATEGORIA  Pediatrics-Endocrinology                   3
# 2  SIN CATEGORIA  Pediatrics-Endocrinology                  50
# 3  SIN CATEGORIA  Pediatrics-Endocrinology                  33
# 4  SIN CATEGORIA  Pediatrics-Endocrinology                  13
#
#    num_procedures  num_medications  number_outpatient  number_emergency  \
# 0               0                1                  0                 0
# 1               0                3                  0                 0
# 2               0                8                  0                 0
# 3               0                4                  0                 0
# 4               0                1                  0                 0
#
#    number_inpatient  diag_1  diag_2  diag_3  number_diagnoses max_glu_serum  \
# 0                 0  250.83     NaN     NaN                 1          None
# 1                 0  250.02   276.0    79.0                 3          None
# 2                 0  250.13   276.0     NaN                 2          None
# 3                 0  250.13   276.0   558.0                 3          None
# 4                 0  250.03   278.0     NaN                 2          None
#
#   A1Cresult metformin repaglinide nateglinide chlorpropamide glimepiride  \
# 0      None        No          No          No             No          No
# 1      None        No          No          No             No          No
# 2      None        No          No          No             No          No
# 3      None        No          No          No             No          No
# 4      None        No          No          No             No          No
#
#   acetohexamide glipizide glyburide tolbutamide pioglitazone rosiglitazone  \
# 0            No        No        No          No           No            No
# 1            No        No        No          No           No            No
# 2            No        No        No          No           No            No
# 3            No        No        No          No           No            No
# 4            No        No        No          No           No            No
#
#   acarbose miglitol troglitazone tolazamide examide citoglipton insulin  \
# 0       No       No           No         No      No          No      No
# 1       No       No           No         No      No          No      No
# 2       No       No           No         No      No          No      No
# 3       No       No           No         No      No          No      No
# 4       No       No           No         No      No          No      No
#
#   glyburide_metformin glipizide_metformin glimepiride_pioglitazone  \
# 0                  No                  No                       No
# 1                  No                  No                       No
# 2                  No                  No                       No
# 3                  No                  No                       No
# 4                  No                  No                       No
#
#   metformin_rosiglitazone metformin_pioglitazone change diabetesMed  \
# 0                      No                     No     No          No
# 1                      No                     No     No          No
# 2                      No                     No     No          No
# 3                      No                     No     No          No
# 4                      No                     No     No          No
#
#   readmitted     n_race n_gender             n_age       n_weight  \
# 0         NO  Caucasian   Female  SMALL_CATEGORIES  SIN CATEGORIA
# 1         NO  Caucasian   Female  SMALL_CATEGORIES  SIN CATEGORIA
# 2         NO  Caucasian     Male  SMALL_CATEGORIES  SIN CATEGORIA
# 3         NO  Caucasian     Male  SMALL_CATEGORIES  SIN CATEGORIA
# 4         NO  Caucasian   Female  SMALL_CATEGORIES  SIN CATEGORIA
#
#     n_payer_code n_medical_specialty n_max_glu_serum n_A1Cresult n_metformin  \
# 0  SIN CATEGORIA    SMALL_CATEGORIES            None        None          No
# 1  SIN CATEGORIA    SMALL_CATEGORIES            None        None          No
# 2  SIN CATEGORIA    SMALL_CATEGORIES            None        None          No
# 3  SIN CATEGORIA    SMALL_CATEGORIES            None        None          No
# 4  SIN CATEGORIA    SMALL_CATEGORIES            None        None          No
#
#   n_repaglinide n_nateglinide n_chlorpropamide n_glimepiride n_acetohexamide  \
# 0            No            No               No            No              No
# 1            No            No               No            No              No
# 2            No            No               No            No              No
# 3            No            No               No            No              No
# 4            No            No               No            No              No
#
#   n_glipizide n_glyburide n_tolbutamide n_pioglitazone n_rosiglitazone  \
# 0          No          No            No             No              No
# 1          No          No            No             No              No
# 2          No          No            No             No              No
# 3          No          No            No             No              No
# 4          No          No            No             No              No
#
#   n_acarbose n_miglitol n_troglitazone n_tolazamide n_examide n_citoglipton  \
# 0         No         No             No           No        No            No
# 1         No         No             No           No        No            No
# 2         No         No             No           No        No            No
# 3         No         No             No           No        No            No
# 4         No         No             No           No        No            No
#
#   n_insulin n_glyburide_metformin n_glipizide_metformin  \
# 0        No                    No                    No
# 1        No                    No                    No
# 2        No                    No                    No
# 3        No                    No                    No
# 4        No                    No                    No
#
#   n_glimepiride_pioglitazone n_metformin_rosiglitazone  \
# 0                         No                        No
# 1                         No                        No
# 2                         No                        No
# 3                         No                        No
# 4                         No                        No
#
#   n_metformin_pioglitazone n_change n_readmitted
# 0                       No       No           NO
# 1                       No       No           NO
# 2                       No       No           NO
# 3                       No       No           NO
# 4                       No       No           NO

# %%
varn = [c for c in df.filter(like='n_').columns.tolist() if c[:2] == 'n_' ]
varn
# Out:
# ['n_race',
#  'n_gender',
#  'n_age',
#  'n_weight',
#  'n_payer_code',
#  'n_medical_specialty',
#  'n_max_glu_serum',
#  'n_A1Cresult',
#  'n_metformin',
#  'n_repaglinide',
#  'n_nateglinide',
#  'n_chlorpropamide',
#  'n_glimepiride',
#  'n_acetohexamide',
#  'n_glipizide',
#  'n_glyburide',
#  'n_tolbutamide',
#  'n_pioglitazone',
#  'n_rosiglitazone',
#  'n_acarbose',
#  'n_miglitol',
#  'n_troglitazone',
#  'n_tolazamide',
#  'n_examide',
#  'n_citoglipton',
#  'n_insulin',
#  'n_glyburide_metformin',
#  'n_glipizide_metformin',
#  'n_glimepiride_pioglitazone',
#  'n_metformin_rosiglitazone',
#  'n_metformin_pioglitazone',
#  'n_change',
#  'n_readmitted']

# %%
df.shape
# Out:
# (101766, 82)

# %%
for v in varn:
    freq(df, v)
# Out:
# Frequencies table for variable n_race
#
#                      FA        FR     FAA       FRA
# Caucasian         76099  0.747784   76099  0.747784
# AfricanAmerican   19210  0.188766   95309  0.936551
# SMALL_CATEGORIES   6457  0.063449  101766  1.000000
#
# Frequencies table for variable n_gender
#
#            FA        FR     FAA       FRA
# Female  54711  0.537616   54711  0.537616
# Male    47055  0.462384  101766  1.000000
#
# Frequencies table for variable n_age
#
#                      FA        FR     FAA       FRA
# [70-80)           26068  0.256156   26068  0.256156
# [60-70)           22483  0.220928   48551  0.477085
# [50-60)           17256  0.169565   65807  0.646650
# [80-90)           17197  0.168986   83004  0.815636
# [40-50)            9685  0.095169   92689  0.910805
# SMALL_CATEGORIES   9077  0.089195  101766  1.000000
#
# Frequencies table for variable n_weight
#
#                    FA   FR     FAA  FRA
# SIN CATEGORIA  101766  1.0  101766  1.0
#
# Frequencies table for variable n_payer_code
#
#                      FA        FR     FAA       FRA
# SIN CATEGORIA     40256  0.395574   40256  0.395574
# MC                32439  0.318761   72695  0.714335
# SMALL_CATEGORIES  22797  0.224014   95492  0.938349
# HM                 6274  0.061651  101766  1.000000
#
# Frequencies table for variable n_medical_specialty
#
#                            FA        FR     FAA       FRA
# SIN CATEGORIA           49949  0.490822   49949  0.490822
# SMALL_CATEGORIES        16825  0.165330   66774  0.656152
# InternalMedicine        14635  0.143810   81409  0.799963
# Emergency/Trauma         7565  0.074337   88974  0.874300
# Family/GeneralPractice   7440  0.073109   96414  0.947409
# Cardiology               5352  0.052591  101766  1.000000
#
# Frequencies table for variable n_max_glu_serum
#
#                      FA        FR     FAA       FRA
# None              96420  0.947468   96420  0.947468
# SMALL_CATEGORIES   5346  0.052532  101766  1.000000
#
# Frequencies table for variable n_A1Cresult
#
#                      FA        FR     FAA       FRA
# None              84748  0.832773   84748  0.832773
# SMALL_CATEGORIES   8802  0.086493   93550  0.919266
# >8                 8216  0.080734  101766  1.000000
#
# Frequencies table for variable n_metformin
#
#            FA        FR     FAA       FRA
# No      83420  0.819724   83420  0.819724
# Steady  18346  0.180276  101766  1.000000
#
# Frequencies table for variable n_repaglinide
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_nateglinide
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_chlorpropamide
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_glimepiride
#
#                      FA        FR     FAA       FRA
# No                96575  0.948991   96575  0.948991
# SMALL_CATEGORIES   5191  0.051009  101766  1.000000
#
# Frequencies table for variable n_acetohexamide
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_glipizide
#
#            FA        FR     FAA       FRA
# No      90410  0.888411   90410  0.888411
# Steady  11356  0.111589  101766  1.000000
#
# Frequencies table for variable n_glyburide
#
#            FA        FR     FAA       FRA
# No      92492  0.908869   92492  0.908869
# Steady   9274  0.091131  101766  1.000000
#
# Frequencies table for variable n_tolbutamide
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_pioglitazone
#
#            FA        FR     FAA       FRA
# No      94790  0.931451   94790  0.931451
# Steady   6976  0.068549  101766  1.000000
#
# Frequencies table for variable n_rosiglitazone
#
#            FA        FR     FAA       FRA
# No      95666  0.940059   95666  0.940059
# Steady   6100  0.059941  101766  1.000000
#
# Frequencies table for variable n_acarbose
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_miglitol
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_troglitazone
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_tolazamide
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_examide
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_citoglipton
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_insulin
#
#            FA        FR     FAA       FRA
# No      47383  0.465607   47383  0.465607
# Steady  30849  0.303137   78232  0.768744
# Down    12218  0.120060   90450  0.888804
# Up      11316  0.111196  101766  1.000000
#
# Frequencies table for variable n_glyburide_metformin
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_glipizide_metformin
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_glimepiride_pioglitazone
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_metformin_rosiglitazone
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_metformin_pioglitazone
#
#         FA   FR     FAA  FRA
# No  101766  1.0  101766  1.0
#
# Frequencies table for variable n_change
#
#        FA        FR     FAA       FRA
# No  54755  0.538048   54755  0.538048
# Ch  47011  0.461952  101766  1.000000
#
# Frequencies table for variable n_readmitted
#
#         FA        FR     FAA       FRA
# NO   54864  0.539119   54864  0.539119
# >30  35545  0.349282   90409  0.888401
# <30  11357  0.111599  101766  1.000000

# %% [markdown]
# ### Unary Variables

# %%
unary = [c for c, count in zip(varn, [df[v].unique().shape[0] for v in varn]) if count == 1]

# %%
varn = [v for v in varn if v not in unary]
len(varn) , varn
# Out:
# (16,
#  ['n_race',
#   'n_gender',
#   'n_age',
#   'n_payer_code',
#   'n_medical_specialty',
#   'n_max_glu_serum',
#   'n_A1Cresult',
#   'n_metformin',
#   'n_glimepiride',
#   'n_glipizide',
#   'n_glyburide',
#   'n_pioglitazone',
#   'n_rosiglitazone',
#   'n_insulin',
#   'n_change',
#   'n_readmitted'])

# %% [markdown]
# ## Countinuous Variables

# %%
df.shape
# Out:
# (101766, 82)

# %%
X = df[varc].copy()

# %%
X.shape
# Out:
# (101766, 14)

# %% [markdown]
# ### Univariate Analysis

# %%
X.describe(percentiles=[0.01,0.1,0.9,0.99])
# Out:
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# count      101766.000000             101766.000000        101766.000000
# mean            2.024006                  3.715642             5.754437
# std             1.445403                  5.280166             4.064081
# min             1.000000                  1.000000             1.000000
# 1%              1.000000                  1.000000             1.000000
# 10%             1.000000                  1.000000             1.000000
# 50%             1.000000                  1.000000             7.000000
# 90%             5.000000                  7.000000             7.000000
# 99%             6.000000                 25.000000            17.000000
# max             8.000000                 28.000000            25.000000
#
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# count     101766.000000       101766.000000   101766.000000    101766.000000
# mean           4.395987           43.095641        1.339730        16.021844
# std            2.985108           19.674362        1.705807         8.127566
# min            1.000000            1.000000        0.000000         1.000000
# 1%             1.000000            1.000000        0.000000         3.000000
# 10%            1.000000           14.000000        0.000000         7.000000
# 50%            4.000000           44.000000        1.000000        15.000000
# 90%            9.000000           67.000000        4.000000        26.000000
# 99%           14.000000           85.000000        6.000000        43.000000
# max           14.000000          132.000000        6.000000        81.000000
#
#        number_outpatient  number_emergency  number_inpatient         diag_1  \
# count      101766.000000     101766.000000     101766.000000  101745.000000
# mean            0.369357          0.197836          0.635566     486.530398
# std             1.267265          0.930472          1.262863     212.307214
# min             0.000000          0.000000          0.000000       3.000000
# 1%              0.000000          0.000000          0.000000      38.000000
# 10%             0.000000          0.000000          0.000000     250.120000
# 50%             0.000000          0.000000          0.000000     435.000000
# 90%             1.000000          1.000000          2.000000     786.000000
# 99%             5.000000          3.000000          6.000000     997.000000
# max            42.000000         76.000000         21.000000     999.000000
#
#               diag_2         diag_3  number_diagnoses
# count  101408.000000  100343.000000     101766.000000
# mean      434.969697     409.669227          7.422607
# std       188.312315     194.995440          1.933600
# min         2.000000       1.000000          1.000000
# 1%         38.000000      15.000000          2.000000
# 10%       250.000000     250.000000          5.000000
# 50%       425.000000     402.000000          8.000000
# 90%       707.000000     707.000000          9.000000
# 99%       996.000000     995.000000          9.000000
# max       999.000000     999.000000         16.000000

# %%
X[varc].hist(figsize=(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'admission_type_id'}>,
#         <AxesSubplot:title={'center':'discharge_disposition_id'}>,
#         <AxesSubplot:title={'center':'admission_source_id'}>,
#         <AxesSubplot:title={'center':'time_in_hospital'}>],
#        [<AxesSubplot:title={'center':'num_lab_procedures'}>,
#         <AxesSubplot:title={'center':'num_procedures'}>,
#         <AxesSubplot:title={'center':'num_medications'}>,
#         <AxesSubplot:title={'center':'number_outpatient'}>],
#        [<AxesSubplot:title={'center':'number_emergency'}>,
#         <AxesSubplot:title={'center':'number_inpatient'}>,
#         <AxesSubplot:title={'center':'diag_1'}>,
#         <AxesSubplot:title={'center':'diag_2'}>],
#        [<AxesSubplot:title={'center':'diag_3'}>,
#         <AxesSubplot:title={'center':'number_diagnoses'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# #### Missing values

# %%
miss = 1 - X[varc].describe().T[['count']] / len(X)
miss
# Out:
#                              count
# admission_type_id         0.000000
# discharge_disposition_id  0.000000
# admission_source_id       0.000000
# time_in_hospital          0.000000
# num_lab_procedures        0.000000
# num_procedures            0.000000
# num_medications           0.000000
# number_outpatient         0.000000
# number_emergency          0.000000
# number_inpatient          0.000000
# diag_1                    0.000206
# diag_2                    0.003518
# diag_3                    0.013983
# number_diagnoses          0.000000

# %%
X.shape, X.dropna().shape, X.dropna().shape[0] / X.shape[0]
# Out:
# ((101766, 14), (100244, 14), 0.9850441208262092)

# %% [markdown]
# #### Imputing missing values

# %%
im = SimpleImputer()

# %%
im.fit(X)
# Out:
# SimpleImputer()

# %%
X[varc] = im.transform(X[varc])

# %%
X.shape, X.dropna().shape, X.dropna().shape[0] / X.shape[0]
# Out:
# ((101766, 14), (101766, 14), 1.0)

# %% [markdown]
# ##### Validating distribution was not altered

# %%
ks = pd.DataFrame( map(lambda v:  (v , ks_2samp(df[v].dropna() , X[v]  ).statistic  ) , varc    ) , columns= ['var','ks']    )

# %%
#Distribution not altered as ks less than 0.1
ks
# Out:
#                          var        ks
# 0          admission_type_id  0.000000
# 1   discharge_disposition_id  0.000000
# 2        admission_source_id  0.000000
# 3           time_in_hospital  0.000000
# 4         num_lab_procedures  0.000000
# 5             num_procedures  0.000000
# 6            num_medications  0.000000
# 7          number_outpatient  0.000000
# 8           number_emergency  0.000000
# 9           number_inpatient  0.000000
# 10                    diag_1  0.000119
# 11                    diag_2  0.002209
# 12                    diag_3  0.007359
# 13          number_diagnoses  0.000000

# %% [markdown]
# #### Variance

# %%
vt = VarianceThreshold(threshold=1.0)

# %%
vt.fit(X[varc])
# Out:
# VarianceThreshold(threshold=1.0)

# %%
wo_variance = [v for v, u in zip( varc , vt.get_support() ) if not(u) ]
wo_variance
# Out:
# ['number_emergency']

# %%
X[wo_variance].hist()
# Out:
# array([[<AxesSubplot:title={'center':'number_emergency'}>]], dtype=object)

# %%
X.drop(wo_variance, axis=1, inplace=True)

# %%
varc = [v for v in varc if v not in wo_variance]
varc
# Out:
# ['admission_type_id',
#  'discharge_disposition_id',
#  'admission_source_id',
#  'time_in_hospital',
#  'num_lab_procedures',
#  'num_procedures',
#  'num_medications',
#  'number_outpatient',
#  'number_inpatient',
#  'diag_1',
#  'diag_2',
#  'diag_3',
#  'number_diagnoses']

# %% [markdown]
# #### Outliers

# %% [markdown]
# ##### Cerca Intercuartil

# %%
# k=2 (moderado) ,  k=3 (fuerte)
k = 2
ext = X[varc].describe(percentiles=[0.25,0.75]).T[['25%','75%','mean']].reset_index()
ext['IQR'] = ext['75%'] - ext['25%'] 
ext['li']  = ext['mean'] - k*ext['IQR']
ext['ls']  = ext['mean'] + k*ext['IQR']
ext = ext[['index','li','ls']]

# %%
for v, li, ls in ext.values:
    X[f'ol_{v}'] = (( X[v] < li ) | ( X[v] > ls ) ).astype(int)

X['ext_iqr'] =  X.filter(like='ol_').max(axis=1)
X.drop(X.filter(like='ol_').columns, axis=1 , inplace=True)

# %%
X['ext_iqr'].value_counts()
# Out:
# 1    101766
# Name: ext_iqr, dtype: int64

# %% [markdown]
# ##### Cerca Percentil

# %%
ext = X[varc].describe(percentiles=[0.005,0.995]).T[['0.5%','99.5%']].reset_index()
for v, li, ls in ext.values:
    X[f'ol_{v}'] = ( (X[v]<li) | (X[v]>ls)  ).astype(int)
    
X['ext'] = X.filter(like='ol_').max(axis=1)

# %%
X.drop(X.filter(like='ol_').columns, axis=1, inplace=True)

# %%
X['ext'].value_counts(True)
# Out:
# 0    0.958493
# 1    0.041507
# Name: ext, dtype: float64

# %% [markdown]
# ##### Adding UM before deleting data

# %%
X[um] = df[um]

# %% [markdown]
# ##### Deleting outliers

# %%
X = X.loc[X["ext"] == 0].reset_index(drop=True).drop(["ext", "ext_iqr"], axis=1)

# %%
X.shape
# Out:
# (97542, 14)

# %%
X.hist(figsize=(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'admission_type_id'}>,
#         <AxesSubplot:title={'center':'discharge_disposition_id'}>,
#         <AxesSubplot:title={'center':'admission_source_id'}>,
#         <AxesSubplot:title={'center':'time_in_hospital'}>],
#        [<AxesSubplot:title={'center':'num_lab_procedures'}>,
#         <AxesSubplot:title={'center':'num_procedures'}>,
#         <AxesSubplot:title={'center':'num_medications'}>,
#         <AxesSubplot:title={'center':'number_outpatient'}>],
#        [<AxesSubplot:title={'center':'number_inpatient'}>,
#         <AxesSubplot:title={'center':'diag_1'}>,
#         <AxesSubplot:title={'center':'diag_2'}>,
#         <AxesSubplot:title={'center':'diag_3'}>],
#        [<AxesSubplot:title={'center':'number_diagnoses'}>,
#         <AxesSubplot:title={'center':'encounter_id'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### Bivariate Analysis

# %%
X[varc].corr()
# Out:
#                           admission_type_id  discharge_disposition_id  \
# admission_type_id                  1.000000                  0.089469
# discharge_disposition_id           0.089469                  1.000000
# admission_source_id                0.117676                  0.025985
# time_in_hospital                  -0.011798                  0.163383
# num_lab_procedures                -0.161593                  0.019667
# num_procedures                     0.126503                  0.013149
# num_medications                    0.075365                  0.105655
# number_outpatient                  0.042662                 -0.010034
# number_inpatient                  -0.035982                  0.026339
# diag_1                            -0.005003                  0.011961
# diag_2                            -0.005765                  0.025721
# diag_3                            -0.003513                  0.029235
# number_diagnoses                  -0.112518                  0.043103
#
#                           admission_source_id  time_in_hospital  \
# admission_type_id                    0.117676         -0.011798
# discharge_disposition_id             0.025985          0.163383
# admission_source_id                  1.000000         -0.010652
# time_in_hospital                    -0.010652          1.000000
# num_lab_procedures                   0.041422          0.303867
# num_procedures                      -0.143073          0.172834
# num_medications                     -0.055014          0.455252
# number_outpatient                    0.048600         -0.016099
# number_inpatient                     0.035781          0.082764
# diag_1                               0.019418         -0.120230
# diag_2                              -0.008489          0.067452
# diag_3                               0.015926          0.084245
# number_diagnoses                     0.070422          0.213647
#
#                           num_lab_procedures  num_procedures  num_medications  \
# admission_type_id                  -0.161593        0.126503         0.075365
# discharge_disposition_id            0.019667        0.013149         0.105655
# admission_source_id                 0.041422       -0.143073        -0.055014
# time_in_hospital                    0.303867        0.172834         0.455252
# num_lab_procedures                  1.000000        0.038878         0.250810
# num_procedures                      0.038878        1.000000         0.354669
# num_medications                     0.250810        0.354669         1.000000
# number_outpatient                  -0.020396       -0.029727         0.053804
# number_inpatient                    0.045791       -0.067318         0.079732
# diag_1                             -0.063098       -0.004696         0.011834
# diag_2                              0.018468        0.049860         0.075340
# diag_3                              0.043302        0.028513         0.069496
# number_diagnoses                    0.148716        0.063127         0.261460
#
#                           number_outpatient  number_inpatient    diag_1  \
# admission_type_id                  0.042662         -0.035982 -0.005003
# discharge_disposition_id          -0.010034          0.026339  0.011961
# admission_source_id                0.048600          0.035781  0.019418
# time_in_hospital                  -0.016099          0.082764 -0.120230
# num_lab_procedures                -0.020396          0.045791 -0.063098
# num_procedures                    -0.029727         -0.067318 -0.004696
# num_medications                    0.053804          0.079732  0.011834
# number_outpatient                  1.000000          0.122677  0.001530
# number_inpatient                   0.122677          1.000000 -0.038589
# diag_1                             0.001530         -0.038589  1.000000
# diag_2                             0.029381          0.010592  0.027551
# diag_3                             0.031452          0.013919  0.019864
# number_diagnoses                   0.099919          0.116276 -0.003466
#
#                             diag_2    diag_3  number_diagnoses
# admission_type_id        -0.005765 -0.003513         -0.112518
# discharge_disposition_id  0.025721  0.029235          0.043103
# admission_source_id      -0.008489  0.015926          0.070422
# time_in_hospital          0.067452  0.084245          0.213647
# num_lab_procedures        0.018468  0.043302          0.148716
# num_procedures            0.049860  0.028513          0.063127
# num_medications           0.075340  0.069496          0.261460
# number_outpatient         0.029381  0.031452          0.099919
# number_inpatient          0.010592  0.013919          0.116276
# diag_1                    0.027551  0.019864         -0.003466
# diag_2                    1.000000  0.094053          0.153021
# diag_3                    0.094053  1.000000          0.166882
# number_diagnoses          0.153021  0.166882          1.000000

# %%
sns.pairplot(X[varc].sample(1000))

# %% [markdown]
# ### Multicolinealidad

# %%
vc = VarClusHi(df=X[varc], feat_list = varc)

# %%
vc.varclus()

# %%
rs = vc.rsquare
rs = rs.sort_values(by=['Cluster','RS_Ratio'] , ascending=[1,1]).reset_index(drop=True)

# %%
rs['id'] = rs.groupby('Cluster').cumcount()+1

# %%
rs
# Out:
#     Cluster                  Variable    RS_Own     RS_NC  RS_Ratio  id
# 0         0          time_in_hospital  0.658325  0.037259  0.354898   1
# 1         0           num_medications  0.590512  0.125790  0.468409   2
# 2         0        num_lab_procedures  0.378203  0.012824  0.629875   3
# 3         0  discharge_disposition_id  0.097236  0.005963  0.908179   4
# 4         1          number_diagnoses  0.509207  0.077225  0.531866   1
# 5         1                    diag_3  0.400956  0.008344  0.604084   2
# 6         1                    diag_2  0.368009  0.005861  0.635717   3
# 7         2         admission_type_id  0.558838  0.016003  0.448337   1
# 8         2       admission_source_id  0.558838  0.020470  0.450381   2
# 9         3         number_outpatient  0.561338  0.007278  0.441878   1
# 10        3          number_inpatient  0.561338  0.009134  0.442706   2
# 11        4                    diag_1  1.000000  0.005133  0.000000   1
# 12        5            num_procedures  1.000000  0.065350  0.000000   1

# %%
varc = rs.loc[ rs['id'] == 1 ]['Variable'].tolist()

# %%
X[varc].hist(figsize=(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'time_in_hospital'}>,
#         <AxesSubplot:title={'center':'number_diagnoses'}>],
#        [<AxesSubplot:title={'center':'admission_type_id'}>,
#         <AxesSubplot:title={'center':'number_outpatient'}>],
#        [<AxesSubplot:title={'center':'diag_1'}>,
#         <AxesSubplot:title={'center':'num_procedures'}>]], dtype=object)

# %% [markdown]
# ### Discretizing

# %%
for v in varc:
    for k in range(2,4):
        X = discretizar(X,v,k)

# %%
X.head()
# Out:
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                3.0                       1.0                  1.0
# 1                1.0                       1.0                  7.0
# 2                1.0                       1.0                  7.0
# 3                1.0                       1.0                  7.0
# 4                1.0                       1.0                  1.0
#
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0               2.0                 3.0             0.0              3.0
# 1               1.0                50.0             0.0              8.0
# 2               1.0                33.0             0.0              4.0
# 3               1.0                55.0             0.0              3.0
# 4               4.0                48.0             0.0              9.0
#
#    number_outpatient  number_inpatient  diag_1  diag_2      diag_3  \
# 0                0.0               0.0  250.02   276.0   79.000000
# 1                0.0               0.0  250.13   276.0  409.669227
# 2                0.0               0.0  250.13   276.0  558.000000
# 3                0.0               1.0  250.13   276.0  409.669227
# 4                0.0               0.0  250.13   276.0  276.000000
#
#    number_diagnoses  encounter_id d_time_in_hospital_2 d_time_in_hospital_3  \
# 0               3.0      53963346       (0.999, 6.154]       (0.999, 4.467]
# 1               2.0      42008934       (0.999, 6.154]       (0.999, 4.467]
# 2               3.0      68750328       (0.999, 6.154]       (0.999, 4.467]
# 3               2.0      89254374       (0.999, 6.154]       (0.999, 4.467]
# 4               3.0      71004000       (0.999, 6.154]       (0.999, 4.467]
#
#   d_number_diagnoses_2 d_number_diagnoses_3 d_admission_type_id_2  \
# 0       (1.999, 6.709]       (1.999, 4.725]        (0.999, 3.566]
# 1       (1.999, 6.709]       (1.999, 4.725]        (0.999, 3.566]
# 2       (1.999, 6.709]       (1.999, 4.725]        (0.999, 3.566]
# 3       (1.999, 6.709]       (1.999, 4.725]        (0.999, 3.566]
# 4       (1.999, 6.709]       (1.999, 4.725]        (0.999, 3.566]
#
#   d_admission_type_id_3 d_number_outpatient_2 d_number_outpatient_3  \
# 0         (2.127, 4.26]       (-0.001, 2.028]       (-0.001, 1.361]
# 1        (0.999, 2.127]       (-0.001, 2.028]       (-0.001, 1.361]
# 2        (0.999, 2.127]       (-0.001, 2.028]       (-0.001, 1.361]
# 3        (0.999, 2.127]       (-0.001, 2.028]       (-0.001, 1.361]
# 4        (0.999, 2.127]       (-0.001, 2.028]       (-0.001, 1.361]
#
#          d_diag_1_2        d_diag_1_3 d_num_procedures_2 d_num_procedures_3
# 0  (7.999, 542.509]  (7.999, 342.774]    (-0.001, 2.358]     (-0.001, 1.49]
# 1  (7.999, 542.509]  (7.999, 342.774]    (-0.001, 2.358]     (-0.001, 1.49]
# 2  (7.999, 542.509]  (7.999, 342.774]    (-0.001, 2.358]     (-0.001, 1.49]
# 3  (7.999, 542.509]  (7.999, 342.774]    (-0.001, 2.358]     (-0.001, 1.49]
# 4  (7.999, 542.509]  (7.999, 342.774]    (-0.001, 2.358]     (-0.001, 1.49]

# %%
vari = X.filter(like='d_').columns.tolist()

# %%
vari
# Out:
# ['d_time_in_hospital_2',
#  'd_time_in_hospital_3',
#  'd_number_diagnoses_2',
#  'd_number_diagnoses_3',
#  'd_admission_type_id_2',
#  'd_admission_type_id_3',
#  'd_number_outpatient_2',
#  'd_number_outpatient_3',
#  'd_diag_1_2',
#  'd_diag_1_3',
#  'd_num_procedures_2',
#  'd_num_procedures_3']

# %%
df.shape, X.shape
# Out:
# ((101766, 82), (97542, 26))

# %% [markdown]
# ## Predictive Power

# %% [markdown]
# ### X and Y

# %%
X = X[um+vari].merge(  df[um+varn] , on = um , how='left' ).reset_index(drop=True)
y = X[um].merge(df[um+tgt], on=um, how='left').reset_index(drop=True)

# %%
X.shape, y.shape
# Out:
# ((97542, 29), (97542, 2))

# %% [markdown]
# #### Train, test split

# %%
Xt, Xv, yt, yv = train_test_split(X, y, train_size=0.7 )

# %%
Xt = Xt.merge( yt, on=um, how='inner' ).reset_index(drop=True)

# %%
Xt.head()
# Out:
#    encounter_id d_time_in_hospital_2 d_time_in_hospital_3  \
# 0     111831816       (0.999, 6.154]       (0.999, 4.467]
# 1     278250660       (0.999, 6.154]       (0.999, 4.467]
# 2      16278096       (0.999, 6.154]       (0.999, 4.467]
# 3      56441946       (0.999, 6.154]       (0.999, 4.467]
# 4     115666302        (6.154, 14.0]       (4.467, 9.006]
#
#   d_number_diagnoses_2 d_number_diagnoses_3 d_admission_type_id_2  \
# 0       (1.999, 6.709]       (4.725, 7.397]        (0.999, 3.566]
# 1         (6.709, 9.0]         (7.397, 9.0]        (0.999, 3.566]
# 2       (1.999, 6.709]       (4.725, 7.397]        (0.999, 3.566]
# 3         (6.709, 9.0]         (7.397, 9.0]        (0.999, 3.566]
# 4         (6.709, 9.0]         (7.397, 9.0]        (0.999, 3.566]
#
#   d_admission_type_id_3 d_number_outpatient_2 d_number_outpatient_3  \
# 0        (0.999, 2.127]       (-0.001, 2.028]       (-0.001, 1.361]
# 1        (0.999, 2.127]       (-0.001, 2.028]       (-0.001, 1.361]
# 2        (0.999, 2.127]       (-0.001, 2.028]       (-0.001, 1.361]
# 3        (0.999, 2.127]       (-0.001, 2.028]       (-0.001, 1.361]
# 4         (2.127, 4.26]       (-0.001, 2.028]       (-0.001, 1.361]
#
#          d_diag_1_2          d_diag_1_3 d_num_procedures_2 d_num_procedures_3  \
# 0  (542.509, 998.0]  (342.774, 634.367]    (-0.001, 2.358]      (1.49, 4.139]
# 1  (7.999, 542.509]    (7.999, 342.774]    (-0.001, 2.358]     (-0.001, 1.49]
# 2  (7.999, 542.509]  (342.774, 634.367]    (-0.001, 2.358]     (-0.001, 1.49]
# 3  (542.509, 998.0]    (634.367, 998.0]    (-0.001, 2.358]     (-0.001, 1.49]
# 4  (542.509, 998.0]  (342.774, 634.367]       (2.358, 6.0]      (1.49, 4.139]
#
#             n_race n_gender    n_age      n_payer_code  \
# 0        Caucasian   Female  [40-50)  SMALL_CATEGORIES
# 1        Caucasian   Female  [40-50)                MC
# 2  AfricanAmerican   Female  [50-60)     SIN CATEGORIA
# 3        Caucasian   Female  [50-60)     SIN CATEGORIA
# 4  AfricanAmerican     Male  [50-60)  SMALL_CATEGORIES
#
#       n_medical_specialty n_max_glu_serum       n_A1Cresult n_metformin  \
# 0        InternalMedicine            None                >8          No
# 1           SIN CATEGORIA            None              None          No
# 2  Family/GeneralPractice            None              None      Steady
# 3           SIN CATEGORIA            None              None          No
# 4        SMALL_CATEGORIES            None  SMALL_CATEGORIES          No
#
#   n_glimepiride n_glipizide n_glyburide n_pioglitazone n_rosiglitazone  \
# 0            No          No          No             No              No
# 1            No          No          No             No              No
# 2            No          No          No         Steady              No
# 3            No          No          No             No              No
# 4            No          No          No             No              No
#
#   n_insulin n_change n_readmitted diabetesMed
# 0    Steady       No           NO         Yes
# 1      Down       Ch          <30         Yes
# 2    Steady       Ch          >30         Yes
# 3        No       No           NO          No
# 4        No       No           NO          No

# %% [markdown]
# ### Best discretized variables (IV Function)

# %%
aux = Xt.pivot_table( index = "d_admission_type_id_3" , 
                          columns = tgt , 
                          values = um , 
                         aggfunc = 'count', 
                         fill_value = 0 )

# %%
aux
# Out:
#                       encounter_id
# diabetesMed                     No    Yes
# d_admission_type_id_3
# (0.999, 2.127]               11236  37536
# (2.127, 4.26]                 2933   9813
# (4.26, 6.0]                   1599   5162

# %%
aux[list(range(2))] = aux/aux.apply(np.sum)

# %%
aux
# Out:
#                       encounter_id                0         1
# diabetesMed                     No    Yes
# d_admission_type_id_3
# (0.999, 2.127]               11236  37536  0.712582  0.714822
# (2.127, 4.26]                 2933   9813  0.186010  0.186875
# (4.26, 6.0]                   1599   5162  0.101408  0.098303

# %%
aux[0]
# Out:
# d_admission_type_id_3
# (0.999, 2.127]    0.712582
# (2.127, 4.26]     0.186010
# (4.26, 6.0]       0.101408
# Name: 0, dtype: float64

# %%
aux[1]
# Out:
# d_admission_type_id_3
# (0.999, 2.127]    0.714822
# (2.127, 4.26]     0.186875
# (4.26, 6.0]       0.098303
# Name: 1, dtype: float64

# %%
aux['w'] = np.log( aux[0] / aux[1] )
aux
# Out:
#                       encounter_id                0         1         w
# diabetesMed                     No    Yes
# d_admission_type_id_3
# (0.999, 2.127]               11236  37536  0.712582  0.714822 -0.003137
# (2.127, 4.26]                 2933   9813  0.186010  0.186875 -0.004642
# (4.26, 6.0]                   1599   5162  0.101408  0.098303  0.031094

# %%
aux['iv'] = ( aux[0] - aux[1] ) * aux['w']
aux
# Out:
#                       encounter_id                0         1         w  \
# diabetesMed                     No    Yes
# d_admission_type_id_3
# (0.999, 2.127]               11236  37536  0.712582  0.714822 -0.003137
# (2.127, 4.26]                 2933   9813  0.186010  0.186875 -0.004642
# (4.26, 6.0]                   1599   5162  0.101408  0.098303  0.031094
#
#                              iv
# diabetesMed
# d_admission_type_id_3
# (0.999, 2.127]         0.000007
# (2.127, 4.26]          0.000004
# (4.26, 6.0]            0.000097

# %%
iv = pd.DataFrame( map( lambda v: calculo_iv(Xt,v,tgt,um[0]), vari  ), columns=['variable','iv']  )
iv['raiz'] = iv['variable'].map(lambda x: '_'.join(x.split('_')[1:2] )  )
iv = iv.sort_values(by=['raiz','iv'],ascending=[1,0]).reset_index(drop=True)

# %%
iv['id'] = iv.groupby('raiz').cumcount()+1
iv = iv.loc[iv['id'] == 1]

# %%
besti = iv['variable'].tolist()
len(besti), besti

# %% [markdown]
# #### Train, test split

# %%
Xt, Xv,yt,yv = train_test_split(X,y,train_size=0.7)

# %%
Xt = Xt.merge(yt,on=um,how='inner')

# %% [markdown]
# ### Best normalized variables

# %%
ivd = pd.DataFrame(map(lambda v:calculo_iv(Xt,v,tgt,um[0]),varn),columns=['variable','iv'])

# %%
ivd

# %%
iv = pd.concat([iv,ivd],ignore_index=True)
#iv = iv.loc[iv['iv'] != np.inf].reset_index(drop=True)
iv = iv.loc[~np.isinf(iv['iv'])].reset_index(drop=True)

# %%
iv.drop(['raiz','id'],axis=1,inplace=True)

# %%
iv.sort_values(by='iv',ascending=False)

# %%
#With iv > 0.1 it would show no best variables, and even with this, it would not show the best discrete variables
#We're adding manually those variables + the best normalized
temp = iv.loc[ (iv['iv'] > 0.02 ) &  ( iv['iv'] < 0.8) ]['variable'].tolist()

# %%
best = besti+temp

# %%
best

# %% [markdown]
# ## WoE Transformation

# %%
X = X[um + best].reset_index(drop=True)

# %%
X.shape, y.shape

# %%
Xt, Xv,yt,yv = train_test_split(X,y,train_size=0.7)

# %%
Xt = Xt.merge(yt,on=um,how='inner')

# %% [markdown]
# ### WoW map

# %%
woe_map = list(map( lambda v: codificacion_woe(  Xt , v, tgt, um[0] ), best  ))

# %%
for v, mapa in woe_map:
    Xt[f'w_{v}'] = Xt[v].replace(mapa)
    Xv[f'w_{v}'] = Xv[v].replace(mapa)

# %%
varw = Xt.filter(like='w_').columns.tolist()

# %%
varw

# %% [markdown]
# ## TAD

# %%
tad = Xt[um + varw].merge(yt, on = um, how='inner').reset_index(drop=True)

# %%
tad

# %%
pd.to_pickle(tad  , 'RINCON_MORALES_DAVID_examen.pkl' , protocol=4  )
